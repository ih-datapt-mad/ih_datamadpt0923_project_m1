# %% [markdown]
# # Bici Park

# %%
import pandas as pd
import requests

# %%
bicipark_df = pd.read_csv('../data/bicipark_stations.csv', sep = ';')

# %%
bicipark_df.head()
# Out:
#    Unnamed: 0  stationId                 stationName  \
# 0           0         74  Bicipark Fuente de la Mora
# 1           1         22             Bicipark Orense
# 2           2         49          Bicipark Montalban
# 3           3         12            Bicipark Almagro
# 4           4          9          Bicipark Recoletos
#
#                          address     city zip_code  total_places  free_places  \
# 0  Estación de Fuente de la Mora   Madrid    28050            10            9
# 1      Avenida General Perón, 27   Madrid    28020            15            9
# 2          Calle de Montalbán, 5   Madrid    28014            16           15
# 3              Calle Almagro, 11   Madrid    28010            16           12
# 4          Paseo de Recoletos, 2   Madrid    28001            10            3
#
#    enabled  reserved_places geometry.type      geometry.coordinates
# 0        1                0         Point  [-3.6630679, 40.4846838]
# 1        1                1         Point    [-3.693897, 40.452973]
# 2        1                0         Point    [-3.690786, 40.418146]
# 3        1                0         Point    [-3.692879, 40.430361]
# 4        0                0         Point    [-3.692245, 40.420354]

# %%
#BICIPARK 
#Escogemos las columnas que nos interesan de bicimad y creamos un nuevo dataframe

bicipark_df_clean = bicipark_df [['stationName', 'address', 'geometry.type', 'zip_code', 'geometry.coordinates']]
bicipark_df_clean
# Out:
#                    stationName                           address  \
# 0   Bicipark Fuente de la Mora     Estación de Fuente de la Mora
# 1              Bicipark Orense         Avenida General Perón, 27
# 2           Bicipark Montalban             Calle de Montalbán, 5
# 3             Bicipark Almagro                 Calle Almagro, 11
# 4           Bicipark Recoletos             Paseo de Recoletos, 2
# 5            Bicipark Recuerdo                  Calle Hiedra, 26
# 6           Bicipark Salamanca      Pl. del Marqués de Salamanca
# 7      Bicipark Villa de Paris         Calle de Orellana, 23, 21
# 8               Bicipark Pitis  Calle Pau Arroyo del Fresno, 181
# 9            Bicipark Aviación         Parking Aviación Española
# 10          Bicipark Canalejas                                 -
#
#    geometry.type zip_code         geometry.coordinates
# 0          Point    28050     [-3.6630679, 40.4846838]
# 1          Point    28020       [-3.693897, 40.452973]
# 2          Point    28014       [-3.690786, 40.418146]
# 3          Point    28010       [-3.692879, 40.430361]
# 4          Point    28001       [-3.692245, 40.420354]
# 5          Point    28036       [-3.678921, 40.472419]
# 6          Point    28006       [-3.679172, 40.430315]
# 7          Point    28004       [-3.693698, 40.425608]
# 8          Point    28049     [-3.7249142, 40.4959425]
# 9          Point    28024  [-3.78369522, 40.383491516]
# 10         Point        -   [-3.6994506, 40.417807676]

# %%
#BICIPARK
#Usamos split para separar mediante la coma
#Añadimos dos columnas de las coordinadas, que son latitud y longitud
#Concatenamos el dataframe limpio que tenemos junto con el nuevo de coordenadas
split_park = bicipark_df_clean['geometry.coordinates'].str.strip('[]').str.split(',', expand=True).astype('float64')
split_park.columns = ['longitude', 'latitude']
df_concat2 = pd.concat([bicipark_df_clean ,split_park],axis=1)
df_concat2
# Out:
#                    stationName                           address  \
# 0   Bicipark Fuente de la Mora     Estación de Fuente de la Mora
# 1              Bicipark Orense         Avenida General Perón, 27
# 2           Bicipark Montalban             Calle de Montalbán, 5
# 3             Bicipark Almagro                 Calle Almagro, 11
# 4           Bicipark Recoletos             Paseo de Recoletos, 2
# 5            Bicipark Recuerdo                  Calle Hiedra, 26
# 6           Bicipark Salamanca      Pl. del Marqués de Salamanca
# 7      Bicipark Villa de Paris         Calle de Orellana, 23, 21
# 8               Bicipark Pitis  Calle Pau Arroyo del Fresno, 181
# 9            Bicipark Aviación         Parking Aviación Española
# 10          Bicipark Canalejas                                 -
#
#    geometry.type zip_code         geometry.coordinates  longitude   latitude
# 0          Point    28050     [-3.6630679, 40.4846838]  -3.663068  40.484684
# 1          Point    28020       [-3.693897, 40.452973]  -3.693897  40.452973
# 2          Point    28014       [-3.690786, 40.418146]  -3.690786  40.418146
# 3          Point    28010       [-3.692879, 40.430361]  -3.692879  40.430361
# 4          Point    28001       [-3.692245, 40.420354]  -3.692245  40.420354
# 5          Point    28036       [-3.678921, 40.472419]  -3.678921  40.472419
# 6          Point    28006       [-3.679172, 40.430315]  -3.679172  40.430315
# 7          Point    28004       [-3.693698, 40.425608]  -3.693698  40.425608
# 8          Point    28049     [-3.7249142, 40.4959425]  -3.724914  40.495942
# 9          Point    28024  [-3.78369522, 40.383491516]  -3.783695  40.383492
# 10         Point        -   [-3.6994506, 40.417807676]  -3.699451  40.417808

# %%
#BICIPARK eliminamos las columnas que no nos interesan
df3 = df_concat2.drop(columns = ['geometry.coordinates', 'geometry.type', 'zip_code']) 
df3
# Out:
#                    stationName                           address  longitude  \
# 0   Bicipark Fuente de la Mora     Estación de Fuente de la Mora  -3.663068
# 1              Bicipark Orense         Avenida General Perón, 27  -3.693897
# 2           Bicipark Montalban             Calle de Montalbán, 5  -3.690786
# 3             Bicipark Almagro                 Calle Almagro, 11  -3.692879
# 4           Bicipark Recoletos             Paseo de Recoletos, 2  -3.692245
# 5            Bicipark Recuerdo                  Calle Hiedra, 26  -3.678921
# 6           Bicipark Salamanca      Pl. del Marqués de Salamanca  -3.679172
# 7      Bicipark Villa de Paris         Calle de Orellana, 23, 21  -3.693698
# 8               Bicipark Pitis  Calle Pau Arroyo del Fresno, 181  -3.724914
# 9            Bicipark Aviación         Parking Aviación Española  -3.783695
# 10          Bicipark Canalejas                                 -  -3.699451
#
#      latitude
# 0   40.484684
# 1   40.452973
# 2   40.418146
# 3   40.430361
# 4   40.420354
# 5   40.472419
# 6   40.430315
# 7   40.425608
# 8   40.495942
# 9   40.383492
# 10  40.417808

# %%
#BICIPARK
#Vemos las columnas que tenemos para despues cambiarle el nombre
df3.columns
# Out:
# Index(['stationName', 'address', 'longitude', 'latitude'], dtype='object')

# %%
#BICIPARK
#Le cambiamos el nombre a la columna 'stationName' y le llamamos 'name'
df3.columns = ['name', 'address', 'longitude', 'latitude'] 
df3
# Out:
#                           name                           address  longitude  \
# 0   Bicipark Fuente de la Mora     Estación de Fuente de la Mora  -3.663068
# 1              Bicipark Orense         Avenida General Perón, 27  -3.693897
# 2           Bicipark Montalban             Calle de Montalbán, 5  -3.690786
# 3             Bicipark Almagro                 Calle Almagro, 11  -3.692879
# 4           Bicipark Recoletos             Paseo de Recoletos, 2  -3.692245
# 5            Bicipark Recuerdo                  Calle Hiedra, 26  -3.678921
# 6           Bicipark Salamanca      Pl. del Marqués de Salamanca  -3.679172
# 7      Bicipark Villa de Paris         Calle de Orellana, 23, 21  -3.693698
# 8               Bicipark Pitis  Calle Pau Arroyo del Fresno, 181  -3.724914
# 9            Bicipark Aviación         Parking Aviación Española  -3.783695
# 10          Bicipark Canalejas                                 -  -3.699451
#
#      latitude
# 0   40.484684
# 1   40.452973
# 2   40.418146
# 3   40.430361
# 4   40.420354
# 5   40.472419
# 6   40.430315
# 7   40.425608
# 8   40.495942
# 9   40.383492
# 10  40.417808

# %%
def nearest(x):
    dist = [distance_meters(interest_df['location.latitude'][x],interest_df['location.longitude'][x] , bicimad_df['latitude'][i], bicimad_df['longitude'][i])[0] for i in range(len(bicimad_df['longitude']))]
    return f'Your nearest station is {bicimad_df['name'][dist.index(min(dist))].split('- ')[1]} located at {round(min(dist),2)} meters from you'
def nearest(x):
    dist = [distance_meters(df1[])]
